# %% [markdown]
# # Charts for Benchmarking

# %% [markdown]
# ### Our Algorithm's Benchmarks

# %%
# %matplotlib inline
import statistics as stats
import matplotlib.pyplot as plt
import statistics as stats
models = ['Airports', 'Email','SF 1500 Node', 'ER 1500 Node', 'GEO 1500 Node','SF 5000 Node', 'ER 5000 Node', 'GEO 5000 Node', 'Physics Collaboration']


gd_sizes_mean = []
gd_sizes_stdev = []
gd_times_mean = []
gd_times_stdev = []

#Airport network benchmark
gd_time_airport = [.517, .515, .498, .502, .502]
gd_size_airport = [154, 154, 154, 155, 155]
gd_sizes_mean.append(stats.mean(gd_size_airport))
gd_sizes_stdev.append(stats.stdev(gd_size_airport))
gd_times_mean.append(stats.mean(gd_time_airport))
gd_times_stdev.append(stats.stdev(gd_time_airport))

#Email network benchmark
gd_time_email = [.45, .484, .470, .459, .462]
gd_size_email = [132, 132, 132, 132, 132]
gd_sizes_mean.append(stats.mean(gd_size_email))
gd_sizes_stdev.append(stats.stdev(gd_size_email))
gd_times_mean.append(stats.mean(gd_time_email))
gd_times_stdev.append(stats.stdev(gd_time_email))

#And so on...
gd_time_1500_SF = [6.851, 6.5, 6.38, 6.4, 7.2]
gd_size_1500_SF = [199, 200, 197, 198, 197]
gd_sizes_mean.append(stats.mean(gd_size_1500_SF))
gd_sizes_stdev.append(stats.stdev(gd_size_1500_SF))
gd_times_mean.append(stats.mean(gd_time_1500_SF))
gd_times_stdev.append(stats.stdev(gd_time_1500_SF))

gd_time_1500_ER = [9.75, 12.2, 10.3, 11.1, 11.1]
gd_size_1500_ER = [175, 164, 170, 166, 163]
gd_sizes_mean.append(stats.mean(gd_size_1500_ER))
gd_sizes_stdev.append(stats.stdev(gd_size_1500_ER))
gd_times_mean.append(stats.mean(gd_time_1500_ER))
gd_times_stdev.append(stats.stdev(gd_time_1500_ER))

gd_time_1500_GEO = [12.6, 13.5, 13.2, 13.1, 12.6]
gd_size_1500_GEO = [133, 136, 138, 130, 132]
gd_sizes_mean.append(stats.mean(gd_size_1500_GEO))
gd_sizes_stdev.append(stats.stdev(gd_size_1500_GEO))
gd_times_mean.append(stats.mean(gd_time_1500_GEO))
gd_times_stdev.append(stats.stdev(gd_time_1500_GEO))

gd_time_5000_SF = [44, 44, 45, 46, 51]
gd_size_5000_SF = [902, 889, 890, 891, 880]
gd_sizes_mean.append(stats.mean(gd_size_5000_SF))
gd_sizes_stdev.append(stats.stdev(gd_size_5000_SF))
gd_times_mean.append(stats.mean(gd_time_5000_SF))
gd_times_stdev.append(stats.stdev(gd_time_5000_SF))

gd_size_5000_ER = [885, 914, 907, 900]
gd_time_5000_ER = [55.9, 56.4, 61, 72]
gd_sizes_mean.append(stats.mean(gd_size_5000_ER))
gd_sizes_stdev.append(stats.stdev(gd_size_5000_ER))
gd_times_mean.append(stats.mean(gd_time_5000_ER))
gd_times_stdev.append(stats.stdev(gd_time_5000_ER))

gd_time_5000_GEO = [82, 81, 82, 84]
gd_size_5000_GEO = [770, 749, 754, 766]
gd_sizes_mean.append(stats.mean(gd_size_5000_GEO))
gd_sizes_stdev.append(stats.stdev(gd_size_5000_GEO))
gd_times_mean.append(stats.mean(gd_time_5000_GEO))
gd_times_stdev.append(stats.stdev(gd_time_5000_GEO))

gd_time_physics = [2.739, 2.725, 2.749, 2.747, 2.731]
gd_size_physics = [2674, 2674, 2678, 2674, 2677]
gd_sizes_mean.append(stats.mean(gd_size_physics))
gd_sizes_stdev.append(stats.stdev(gd_size_physics))
gd_times_mean.append(stats.mean(gd_time_physics))
gd_times_stdev.append(stats.stdev(gd_time_physics))

# %% [markdown]
# ### Z3 Benchmarks

# %%
z3_sizes_mean = []
z3_sizes_stdev = []
z3_times_mean = []
z3_times_stdev = []

z3_time_airport = [2.94, 3.20, 2.94, 3.12, 3.01]
z3_size_airport = [145, 145, 145, 145, 145]
z3_sizes_mean.append(stats.mean(z3_size_airport))
z3_sizes_stdev.append(stats.stdev(z3_size_airport))
z3_times_mean.append(stats.mean(z3_time_airport))
z3_times_stdev.append(stats.stdev(z3_time_airport))

z3_time_email = [2.58, 2.65, 2.68, 2.57,2.55]
z3_size_email = [109, 109, 109, 109, 109]
z3_sizes_mean.append(stats.mean(z3_size_email))
z3_sizes_stdev.append(stats.stdev(z3_size_email))
z3_times_mean.append(stats.mean(z3_time_email))
z3_times_stdev.append(stats.stdev(z3_time_email))

for _ in range(7):
    z3_sizes_mean.append(0)
    z3_sizes_stdev.append(0)
    z3_times_mean.append(0)
    z3_times_stdev.append(0)

# %% [markdown]
# ## Networkx Benchmarks

# %%
networkx_sizes_mean = []
networkx_sizes_stdev = []
networkx_times_mean = []
networkx_times_stdev = []

networkx_time_airports = [4.145, 3.9, 3.419, 3.69, 3.13]
networkx_size_airports = [587, 587, 587, 587, 587]
networkx_sizes_mean.append(stats.mean(networkx_size_airports))
networkx_sizes_stdev.append(stats.stdev(networkx_size_airports))
networkx_times_mean.append(stats.mean(networkx_time_airports))
networkx_times_stdev.append(stats.stdev(networkx_time_airports))

networkx_time_email = [2.5, 2.6, 3.7, 2.9, 3.1]
networkx_size_email = [580, 580, 580, 580, 580]
networkx_sizes_mean.append(stats.mean(networkx_size_email))
networkx_sizes_stdev.append(stats.stdev(networkx_size_email))
networkx_times_mean.append(stats.mean(networkx_time_email))
networkx_times_stdev.append(stats.stdev(networkx_time_email))

networkx_time_1500_SF = [2.9, 3.3, 3.3, 3.0, 3.7]
networkx_size_1500_SF = [292, 292, 292, 292, 292]
networkx_sizes_mean.append(stats.mean(networkx_size_1500_SF))
networkx_sizes_stdev.append(stats.stdev(networkx_size_1500_SF))
networkx_times_mean.append(stats.mean(networkx_time_1500_SF))
networkx_times_stdev.append(stats.stdev(networkx_time_1500_SF))

networkx_time_1500_ER = [4.6, 4.7, 4.3, 4.2, 4.8]
networkx_size_1500_ER = [380, 380, 380, 380, 380]
networkx_sizes_mean.append(stats.mean(networkx_size_1500_ER))
networkx_sizes_stdev.append(stats.stdev(networkx_size_1500_ER))
networkx_times_mean.append(stats.mean(networkx_time_1500_ER))
networkx_times_stdev.append(stats.stdev(networkx_time_1500_ER))

networkx_time_1500_GEO = [7.6, 7.6, 7.7, 7.9, 7.4]
networkx_size_1500_GEO = [1236, 1236, 1236, 1236, 1236]
networkx_sizes_mean.append(stats.mean(networkx_size_1500_GEO))
networkx_sizes_stdev.append(stats.stdev(networkx_size_1500_GEO))
networkx_times_mean.append(stats.mean(networkx_time_1500_GEO))
networkx_times_stdev.append(stats.stdev(networkx_time_1500_GEO))

networkx_time_5000_SF = [30, 31, 31, 31, 36]
networkx_size_5000_SF = [1644, 1644, 1644, 1644, 1644]
networkx_sizes_mean.append(stats.mean(networkx_size_5000_SF))
networkx_sizes_stdev.append(stats.stdev(networkx_size_5000_SF))
networkx_times_mean.append(stats.mean(networkx_time_5000_SF))
networkx_times_stdev.append(stats.stdev(networkx_time_5000_SF))

networkx_time_5000_ER = [53, 55, 55, 54, 55]
networkx_size_5000_ER = [2714, 2714, 2714, 2714, 2714]
networkx_sizes_mean.append(stats.mean(networkx_size_5000_ER))
networkx_sizes_stdev.append(stats.stdev(networkx_size_5000_ER))
networkx_times_mean.append(stats.mean(networkx_time_5000_ER))
networkx_times_stdev.append(stats.stdev(networkx_time_5000_ER))

networkx_time_5000_GEO = [64, 65, 64, 64, 65]
networkx_size_5000_GEO = [4133, 4133, 4133, 4133, 4133]
networkx_sizes_mean.append(stats.mean(networkx_size_5000_GEO))
networkx_sizes_stdev.append(stats.stdev(networkx_size_5000_GEO))
networkx_times_mean.append(stats.mean(networkx_time_5000_GEO))
networkx_times_stdev.append(stats.stdev(networkx_time_5000_GEO))

networkx_time_phy = [2.9, 2.3, 2.3, 2.2, 2.3]
networkx_size_phy = [3814, 3814, 3814, 3814, 3814]
networkx_sizes_mean.append(stats.mean(networkx_size_phy))
networkx_sizes_stdev.append(stats.stdev(networkx_size_phy))
networkx_times_mean.append(stats.mean(networkx_time_phy))
networkx_times_stdev.append(stats.stdev(networkx_time_phy))

# %% [markdown]
# ### Highest Degree Benchmarks

# %%
highest_deg_sizes_mean = []
highest_deg_sizes_stdev = []
highest_deg_times_mean = []
highest_deg_times_stdev = []

highest_deg_time_airports = [1.137, 1.15, 1.126, 1.206, 1.129]
highest_deg_size_airports = [620, 620,619, 619, 622]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_airports))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_airports))
highest_deg_times_mean.append(stats.mean(highest_deg_time_airports))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_airports))

highest_deg_time_email = [.627, .619, .642, .640, .620]
highest_deg_size_email = [283, 284, 280, 278, 278]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_email))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_email))
highest_deg_times_mean.append(stats.mean(highest_deg_time_email))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_email))

highest_deg_time_1500_SF = [.923, .644, .636, .624, .644]
highest_deg_size_1500_SF = [201, 201, 200, 209, 206]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_1500_SF))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_1500_SF))
highest_deg_times_mean.append(stats.mean(highest_deg_time_1500_SF))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_1500_SF))
                            
highest_deg_time_1500_ER = [.688, .721, .715, .708, .846]
highest_deg_size_1500_ER = [202, 198, 208, 202, 204]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_1500_ER))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_1500_ER))
highest_deg_times_mean.append(stats.mean(highest_deg_time_1500_ER))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_1500_ER))

highest_deg_time_1500_GEO = [1.179, 1.219, 1.233, 1.183, 1.451]
highest_deg_size_1500_GEO = [131, 126, 126, 124, 130]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_1500_GEO))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_1500_GEO))
highest_deg_times_mean.append(stats.mean(highest_deg_time_1500_GEO))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_1500_GEO))

highest_deg_time_5000_SF = [10.19, 9.989, 9.491, 9.36, 10.92]
highest_deg_size_5000_SF = [1039, 1034, 1036, 1028, 1031]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_5000_SF))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_5000_SF))
highest_deg_times_mean.append(stats.mean(highest_deg_time_5000_SF))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_5000_SF))

highest_deg_time_5000_ER = [11.6, 11.5, 11.3, 11.9, 11.9]
highest_deg_size_5000_ER = [875, 878, 872, 878, 884]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_5000_ER))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_5000_ER))
highest_deg_times_mean.append(stats.mean(highest_deg_time_5000_ER))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_5000_ER))


highest_deg_time_5000_GEO = [12.78, 12.97, 13.813, 12.767, 13.289]
highest_deg_size_5000_GEO = [719, 718, 718, 712, 713]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_5000_GEO))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_5000_GEO))
highest_deg_times_mean.append(stats.mean(highest_deg_time_5000_GEO))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_5000_GEO))

highest_deg_time_phy = [43.3, 51.2, 41.69, 43, 48.1]
highest_deg_size_phy = [3169, 3131, 3172, 3141, 3150]
highest_deg_sizes_mean.append(stats.mean(highest_deg_size_phy))
highest_deg_sizes_stdev.append(stats.stdev(highest_deg_size_phy))
highest_deg_times_mean.append(stats.mean(highest_deg_time_phy))
highest_deg_times_stdev.append(stats.stdev(highest_deg_time_phy))

# %% [markdown]
# ### Lowest Degree Benchmarks

# %%
lowest_deg_sizes_mean = []
lowest_deg_sizes_stdev = []
lowest_deg_times_mean = []
lowest_deg_times_stdev = []

lowest_deg_time_airports = [1.3, 1.3, 1.32, 1.3, 1.33]
lowest_deg_size_airports = [441, 442, 437, 434, 442]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_airports))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_airports))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_airports))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_airports))

lowest_deg_time_email = [.74, .76, .76, .76, .75]
lowest_deg_size_email = [421, 421, 422, 422, 423]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_email))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_email))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_email))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_email))

lowest_deg_time_1500_SF = [1.3, 1.3, 1.3, 1.3, 1.4]
lowest_deg_size_1500_SF = [437, 436, 433, 440, 437]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_1500_SF))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_1500_SF))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_1500_SF))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_1500_SF))

lowest_deg_time_1500_ER = [1.2, 1.2, 1.2, 1.2, 1.3]
lowest_deg_size_1500_ER = [286, 288, 288, 295, 284]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_1500_ER))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_1500_ER))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_1500_ER))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_1500_ER))

lowest_deg_size_1500_GEO = [207, 209, 208, 206, 209]
lowest_deg_time_1500_GEO = [1.2, 1.3, 1.2, 1.1, 1.6]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_1500_GEO))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_1500_GEO))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_1500_GEO))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_1500_GEO))

lowest_deg_time_5000_SF = [16.7, 15.65, 15.85, 15.2, 15.32]
lowest_deg_size_5000_SF = [2065, 2060, 2060, 2060, 2060]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_5000_SF))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_5000_SF))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_5000_SF))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_5000_SF))

lowest_deg_time_5000_ER = [13.9, 14.2, 14.2, 14.3, 14.3]
lowest_deg_size_5000_ER = [1467, 1471, 1477, 1468, 1472]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_5000_ER))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_5000_ER))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_5000_ER))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_5000_ER))

lowest_deg_time_5000_GEO = [12.9, 12.7, 13.1, 13.3, 12.7]
lowest_deg_size_5000_GEO = [1119, 1104, 1125, 1120, 1115]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_5000_GEO))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_5000_GEO))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_5000_GEO))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_5000_GEO))

lowest_deg_time_phy = [76.6, 72.1, 74.5, 80.8, 74.9]
lowest_deg_size_phy = [4891, 4892, 4894, 4894, 4892]
lowest_deg_sizes_mean.append(stats.mean(lowest_deg_size_phy))
lowest_deg_sizes_stdev.append(stats.stdev(lowest_deg_size_phy))
lowest_deg_times_mean.append(stats.mean(lowest_deg_time_phy))
lowest_deg_times_stdev.append(stats.stdev(lowest_deg_time_phy))

# %% [markdown]
# # Dominating Set Size for All Algo-Network Combos

# %%
plt.figure(figsize=(15,9))
plt.rcParams.update({'font.size': 14})
x = [x + 1 for x in range(0, len(models)*2, 2)]
plt.title("Dominating Set Cardinality for All Algorithm-Network Pairs")
plt.xticks(x, models, rotation="vertical")
plt.bar([pos-0.6 for pos in x], z3_sizes_mean,yerr=z3_sizes_stdev, label="Z3", width=0.3,color='#5DA5DA',align='center')
plt.bar([pos-0.3 for pos in x], gd_sizes_mean, yerr=gd_sizes_stdev, label="Ours", width=0.3,color='#FAA43A',align='center')
plt.bar([pos-0.0 for pos in x], networkx_sizes_mean,yerr=networkx_sizes_stdev, label="NetworkX", width=0.3,color='#60BD68',align='center')
plt.bar([pos+0.3 for pos in x], highest_deg_sizes_mean, label="Highest Degree", yerr=highest_deg_sizes_stdev, width=0.3,color='#F17CB0',align='center')
plt.bar([pos+0.6 for pos in x], lowest_deg_sizes_mean, label="Lowest Degree", yerr=lowest_deg_sizes_stdev,width=0.3,color='#B2912F',align='center')
plt.ylabel("Cardinality of Dominating Set")
plt.legend(loc=2, title="Algorithm")
#plt.yscale('log')
plt.show()

# %% [markdown]
# ## Dominating Set Size for Algo-Model Network Combos

# %%
models = ['SF 1500 Node', 'ER 1500 Node', 'GEO 1500 Node','SF 5000 Node', 'ER 5000 Node', 'GEO 5000 Node' ]
plt.figure(figsize=(15,9))
plt.rcParams.update({'font.size': 14})
x = [x + 1 for x in range(0, len(models)*2, 2)]
plt.title("Dominating Set Cardinality for Algorithm-Model Network Pairs")
plt.xticks(x, models, rotation="vertical")
plt.bar([pos-0.4 for pos in x], gd_sizes_mean[2:-1], yerr=gd_sizes_stdev[2:-1], label="Ours", width=0.3,color='#FAA43A',align='center')
plt.bar([pos-0.1 for pos in x], networkx_sizes_mean[2:-1],yerr=networkx_sizes_stdev[2:-1], label="NetworkX", width=0.3,color='#60BD68',align='center')
plt.bar([pos+0.2 for pos in x], highest_deg_sizes_mean[2:-1], label="Highest Degree", yerr=highest_deg_sizes_stdev[2:-1], width=0.3,color='#F17CB0',align='center')
plt.bar([pos+0.5 for pos in x], lowest_deg_sizes_mean[2:-1], label="Lowest Degree", yerr=lowest_deg_sizes_stdev[2:-1],width=0.3,color='#B2912F',align='center')
plt.ylabel("Cardinality of Dominating Set")
plt.legend(loc=2, title="Algorithm")
plt.show()

# %% [markdown]
# ## Cardinality for Algorithm-Real World Network Pairs

# %%
models = ['Airports', 'Email', 'Physics Collaboration']
plt.figure(figsize=(15,9))
plt.rcParams.update({'font.size': 14})
x = [x + 1 for x in range(0, len(models)*2, 2)]
plt.title("Dominating Set Cardinality for Algorithm-Real World Network Pairs")
plt.xticks(x, models, rotation="vertical")
a = gd_sizes_stdev[:2]  + [gd_sizes_stdev[-1]]
plt.bar([pos-0.6 for pos in x], z3_sizes_mean[:3],yerr=z3_sizes_stdev[:3], label="Z3", width=0.3,color='#5DA5DA',align='center')
plt.bar([pos-0.3 for pos in x], gd_sizes_mean[:2]  + [gd_sizes_mean[-1]], yerr=a, label="Ours", width=0.3,color='#FAA43A',align='center')
plt.bar([pos-0.0 for pos in x], networkx_sizes_mean[:2]  + [networkx_sizes_mean[-1]],yerr=networkx_sizes_stdev[:2]  + [networkx_sizes_stdev[-1]], label="NetworkX", width=0.3,color='#60BD68',align='center')
plt.bar([pos+0.3 for pos in x], highest_deg_sizes_mean[:2]  + [highest_deg_sizes_mean[-1]], label="Highest Degree", yerr=highest_deg_sizes_stdev[:2]  + [highest_deg_sizes_stdev[-1]], width=0.3,color='#F17CB0',align='center')
plt.bar([pos+0.6 for pos in x], lowest_deg_sizes_mean[:2]  + [lowest_deg_sizes_mean[-1]], label="Lowest Degree", yerr=lowest_deg_sizes_stdev[:2]  + [lowest_deg_sizes_stdev[-1]],width=0.3,color='#B2912F',align='center')
plt.ylabel("Cardinality of Dominating Set")
plt.legend(loc=2, title="Algorithm")
plt.show()

# %% [markdown]
# # Network Size vs.Running Time

# %%
models = ['Airports', 'Email','SF 1500 Node', 'ER 1500 Node', 'GEO 1500 Node','SF 5000 Node', 'ER 5000 Node', 'GEO 5000 Node', 'Physics Collaboration' ]

plt.figure(figsize=(15,9))
plt.rcParams.update({'font.size': 14})
x = [x + 1 for x in range(0, len(models)*2, 2)]
plt.title("Run Time of All Algorithm-Network Pairs")
plt.xticks(x, models, rotation="vertical")
plt.bar([pos-0.6 for pos in x], z3_times_mean,yerr=z3_times_stdev, label="Z3", width=0.3,color='#5DA5DA',align='center')
plt.bar([pos-0.3 for pos in x], gd_times_mean, yerr=gd_times_stdev, label="Ours", width=0.3,color='#FAA43A',align='center')
plt.bar([pos-0.0 for pos in x], networkx_times_mean,yerr=networkx_times_stdev, label="NetworkX", width=0.3,color='#60BD68',align='center')
plt.bar([pos+0.3 for pos in x], highest_deg_times_mean, label="Highest Degree", yerr=highest_deg_times_stdev, width=0.3,color='#F17CB0',align='center')
plt.bar([pos+0.6 for pos in x], lowest_deg_times_mean, label="Lowest Degree", yerr=lowest_deg_times_stdev,width=0.3,color='#B2912F',align='center')
plt.ylabel("Running Time in Seconds")
plt.legend(loc=2, title="Algorithm")
#plt.yscale('log')
plt.show()

# %% [markdown]
# ## Running Time for each Algorithm-Model Network Pair

# %%
models = ['SF 1500 Node', 'ER 1500 Node', 'GEO 1500 Node','SF 5000 Node', 'ER 5000 Node', 'GEO 5000 Node' ]
plt.figure(figsize=(15,9))
plt.rcParams.update({'font.size': 14})
x = [x + 1 for x in range(0, len(models)*2, 2)]
plt.title("Run Time of Algorithm-Model Network Pairs")
plt.xticks(x, models, rotation="vertical")
plt.bar([pos-0.4 for pos in x], gd_times_mean[2:-1], yerr=gd_times_stdev[2:-1], label="Ours", width=0.3,color='#FAA43A',align='center')
plt.bar([pos-0.1 for pos in x], networkx_times_mean[2:-1],yerr=networkx_times_stdev[2:-1], label="NetworkX", width=0.3,color='#60BD68',align='center')
plt.bar([pos+0.2 for pos in x], highest_deg_times_mean[2:-1], label="Highest Degree", yerr=highest_deg_times_stdev[2:-1], width=0.3,color='#F17CB0',align='center')
plt.bar([pos+0.5 for pos in x], lowest_deg_times_mean[2:-1], label="Lowest Degree", yerr=lowest_deg_times_stdev[2:-1],width=0.3,color='#B2912F',align='center')
plt.ylabel("Running Time in Seconds")
plt.legend(loc=2, title="Algorithm")
plt.show()

# %% [markdown]
# ## Run Time of Algorithm - Real World Network Pairs

# %%
models = ['Airports', 'Email', 'Physics Collaboration']
plt.figure(figsize=(15,9))
plt.rcParams.update({'font.size': 14})
x = [x + 1 for x in range(0, len(models)*2, 2)]
plt.title("Run Time of Algorithm-Real World Network Pairs")
plt.xticks(x, models, rotation="vertical")
a = gd_times_stdev[:2]  + [gd_times_stdev[-1]]
plt.bar([pos-0.6 for pos in x], z3_times_mean[:3],yerr=z3_times_stdev[:3], label="Z3", width=0.3,color='#5DA5DA',align='center')
plt.bar([pos-0.3 for pos in x], gd_times_mean[:2]  + [gd_times_mean[-1]], yerr=a, label="Ours", width=0.3,color='#FAA43A',align='center')
plt.bar([pos-0.0 for pos in x], networkx_times_mean[:2]  + [networkx_times_mean[-1]],yerr=networkx_times_stdev[:2]  + [networkx_times_stdev[-1]], label="NetworkX", width=0.3,color='#60BD68',align='center')
plt.bar([pos+0.3 for pos in x], highest_deg_times_mean[:2]  + [highest_deg_times_mean[-1]], label="Highest Degree", yerr=highest_deg_times_stdev[:2]  + [highest_deg_times_stdev[-1]], width=0.3,color='#F17CB0',align='center')
plt.bar([pos+0.6 for pos in x], lowest_deg_times_mean[:2]  + [lowest_deg_times_mean[-1]], label="Lowest Degree", yerr=lowest_deg_times_stdev[:2]  + [lowest_deg_times_stdev[-1]],width=0.3,color='#B2912F',align='center')
plt.ylabel("Running Time in Seconds")
plt.legend(loc=2, title="Algorithm")
plt.show()

# %% [markdown]
# ## Cardinality Found By Our Algo vs. Num of our Graphlets present

# %%
import numpy as np
models = ['Airports', 'Email','SF 1500 Node', 'ER 1500 Node', 'GEO 1500 Node','SF 5000 Node', 'ER 5000 Node', 'GEO 5000 Node', 'Physics Collaboration' ]
orbitCount = [32950441, 7850784, 906607, 411695, 1698546, 873644, 377931, 906005, 684592]
graph_sizes = [1575, 1005, 1576, 1576, 1576, 5442, 5242, 5242, 9878]
tot_orbit_count = [504677775, 307553582, 166281317,43593087, 19348420, 197134812, 19774427, 8736187,16743104]
normalizedOrbit = []
normalizedCardinality = []
for i in range(len(models)):
    normalizedOrbit.append(float(tot_orbit_count[i])/float(graph_sizes[i]))
    normalizedCardinality.append(float(gd_sizes_mean[i])/float(graph_sizes[i]))

plt.figure(figsize=(15,9))
plt.rcParams.update({'font.size': 14})
#x = [x + 1 for x in range(0, len(models)*2, 2)]
plt.title("Normalized Total Orbits vs. Normalized Cardinality")
plt.plot(np.unique(normalizedOrbit), np.poly1d(np.polyfit(normalizedOrbit, normalizedCardinality, 1))(np.unique(normalizedOrbit)))
#plt.xticks(x, models, rotation="vertical")
plt.scatter(normalizedOrbit, normalizedCardinality, s=70, color='#60BD68')
plt.ylabel("Cardinality to Network Size Ratio")
plt.xlabel("Orbit Count to Network Size Ratio")
#plt.legend(loc=2, title="Algorithm")
#plt.yscale('log')
plt.show()

# %% [markdown]
# ## Cardinality Found by Our Algo vs. Clustering Coefficient

# %%
cc = [.504, .407, .047, .0139, .526, .0135, .0022, .498, .472]

models = ['Airports', 'Email','SF 1500 Node', 'ER 1500 Node', 'GEO 1500 Node','SF 5000 Node', 'ER 5000 Node', 'GEO 5000 Node', 'Physics Collaboration' ]
orbitCount = [32950441, 7850784, 906607, 411695, 1698546, 873644, 377931, 906005, 684592]
graph_sizes = [1575, 1005, 1576, 1576, 1576, 5442, 5242, 5242, 9878]
tot_orbit_count = [504677775, 307553582, 166281317,43593087, 19348420, 197134812, 19774427, 8736187,16743104]
normalizedOrbit = []
normalizedCardinality = []
for i in range(len(models)):
    normalizedOrbit.append(float(tot_orbit_count[i])/float(graph_sizes[i]))
    normalizedCardinality.append(float(gd_sizes_mean[i])/float(graph_sizes[i]))
normalizedOrbit = cc
plt.figure(figsize=(15,9))
plt.rcParams.update({'font.size': 14})
#x = [x + 1 for x in range(0, len(models)*2, 2)]
plt.title("Normalized Total Orbits vs. Normalized Cardinality")
plt.plot(np.unique(normalizedOrbit), np.poly1d(np.polyfit(normalizedOrbit, normalizedCardinality, 1))(np.unique(normalizedOrbit)))
#plt.xticks(x, models, rotation="vertical")
plt.scatter(normalizedOrbit, normalizedCardinality, s=70, color='#60BD68')
plt.ylabel("Cardinality to Network Size Ratio")
plt.xlabel("Orbit Count to Network Size Ratio")
#plt.legend(loc=2, title="Algorithm")
#plt.yscale('log')
plt.show()
